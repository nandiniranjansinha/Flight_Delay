# %%
# !pip install pandas pandasql matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from pandasql) (2.0.41)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->pandasql) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->pandasql) (4.14.1)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=754b072114376d1b37900c447f576cbe01078c83a1d0df187edd42ab5c5d6456
#   Stored in directory: /root/.cache/pip/wheels/68/5d/a5/edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandasql as ps

# %%
sns.set(style='whitegrid') # to make the graphs look pretty

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'Feb_2025.csv',
#  'Jan_2025.csv',
#  'Apr_2025.csv',
#  'Mar_2025.csv',
#  'sample_data']

# %%
jan = pd.read_csv('Jan_2025.csv')
feb = pd.read_csv('Feb_2025.csv')
mar = pd.read_csv('Mar_2025.csv')
apr = pd.read_csv('Apr_2025.csv')

# %%
# Combining the csv files
df = pd.concat([jan,feb,mar,apr], ignore_index = True)
# ignore_index to remove the index (unnecessary column)

# %%
df.shape
# Out:
# (2229453, 26)

# %%
df.columns
# Out:
# Index(['FL_DATE', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST',
#        'DEST_CITY_NAME', 'DEST_STATE_NM', 'DEP_DELAY', 'DEP_DELAY_NEW',
#        'DEP_DEL15', 'ARR_DELAY', 'ARR_DELAY_NEW', 'ARR_DEL15', 'CANCELLED',
#        'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY'],
#       dtype='object')

# %%
df.head(10)
# Out:
#                 FL_DATE OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN  \
# 0  1/1/2025 12:00:00 AM                AA   N101NN                164    SFO
# 1  1/1/2025 12:00:00 AM                AA   N101NN                 76    JFK
# 2  1/1/2025 12:00:00 AM                AA   N102UW               3244    SAT
# 3  1/1/2025 12:00:00 AM                AA   N103NN                185    JFK
# 4  1/1/2025 12:00:00 AM                AA   N103NN               2455    BOS
# 5  1/1/2025 12:00:00 AM                AA   N103NN                  4    LAX
# 6  1/1/2025 12:00:00 AM                AA   N103US               1324    PHX
# 7  1/1/2025 12:00:00 AM                AA   N103US               1324    SMF
# 8  1/1/2025 12:00:00 AM                AA   N103US               1958    CMH
# 9  1/1/2025 12:00:00 AM                AA   N103US               2808    PHX
#
#     ORIGIN_CITY_NAME ORIGIN_STATE_NM DEST     DEST_CITY_NAME   DEST_STATE_NM  \
# 0  San Francisco, CA      California  JFK       New York, NY        New York
# 1       New York, NY        New York  SFO  San Francisco, CA      California
# 2    San Antonio, TX           Texas  CLT      Charlotte, NC  North Carolina
# 3       New York, NY        New York  LAX    Los Angeles, CA      California
# 4         Boston, MA   Massachusetts  LAX    Los Angeles, CA      California
# 5    Los Angeles, CA      California  JFK       New York, NY        New York
# 6        Phoenix, AZ         Arizona  SMF     Sacramento, CA      California
# 7     Sacramento, CA      California  PHX        Phoenix, AZ         Arizona
# 8       Columbus, OH            Ohio  PHX        Phoenix, AZ         Arizona
# 9        Phoenix, AZ         Arizona  OMA          Omaha, NE        Nebraska
#
#    ...  CANCELLED  DIVERTED  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  DISTANCE  \
# 0  ...        0.0       0.0             342.0                308.0    2586.0
# 1  ...        0.0       0.0             400.0                388.0    2586.0
# 2  ...        0.0       0.0             167.0                145.0    1095.0
# 3  ...        0.0       0.0             389.0                395.0    2475.0
# 4  ...        0.0       0.0             399.0                375.0    2611.0
# 5  ...        0.0       0.0             331.0                285.0    2475.0
# 6  ...        0.0       0.0             128.0                131.0     647.0
# 7  ...        0.0       0.0             110.0                 99.0     647.0
# 8  ...        0.0       0.0             272.0                260.0    1670.0
# 9  ...        0.0       0.0             156.0                148.0    1037.0
#
#    CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0            NaN            NaN        NaN             NaN
# 1            NaN            NaN        NaN             NaN
# 2            NaN            NaN        NaN             NaN
# 3            NaN            NaN        NaN             NaN
# 4            NaN            NaN        NaN             NaN
# 5            NaN            NaN        NaN             NaN
# 6           30.0            0.0        3.0             0.0
# 7            NaN            NaN        NaN             NaN
# 8            NaN            NaN        NaN             NaN
# 9            NaN            NaN        NaN             NaN
#
#    LATE_AIRCRAFT_DELAY
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  0.0
# 7                  NaN
# 8                  NaN
# 9                  NaN
#
# [10 rows x 26 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['OP_CARRIER_FL_NUM'].plot(kind='hist', bins=20, title='OP_CARRIER_FL_NUM')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['DEP_DELAY'].plot(kind='hist', bins=20, title='DEP_DELAY')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['DEP_DELAY_NEW'].plot(kind='hist', bins=20, title='DEP_DELAY_NEW')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['DEP_DEL15'].plot(kind='hist', bins=20, title='DEP_DEL15')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('TAIL_NUM').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('ORIGIN').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('ORIGIN_CITY_NAME').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('ORIGIN_STATE_NM').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='OP_CARRIER_FL_NUM', y='DEP_DELAY', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='DEP_DELAY', y='DEP_DELAY_NEW', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='DEP_DELAY_NEW', y='DEP_DEL15', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='DEP_DEL15', y='ARR_DELAY', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['FL_DATE']
#   ys = series['OP_CARRIER_FL_NUM']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('FL_DATE', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('TAIL_NUM')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='TAIL_NUM', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('FL_DATE')
# _ = plt.ylabel('OP_CARRIER_FL_NUM')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['FL_DATE']
#   ys = series['OP_CARRIER_FL_NUM']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('FL_DATE', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('ORIGIN')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='ORIGIN', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('FL_DATE')
# _ = plt.ylabel('OP_CARRIER_FL_NUM')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['FL_DATE']
#   ys = series['OP_CARRIER_FL_NUM']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('FL_DATE', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('ORIGIN_CITY_NAME')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='ORIGIN_CITY_NAME', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('FL_DATE')
# _ = plt.ylabel('OP_CARRIER_FL_NUM')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['FL_DATE']
#   ys = series['OP_CARRIER_FL_NUM']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('FL_DATE', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('ORIGIN_STATE_NM')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='ORIGIN_STATE_NM', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('FL_DATE')
# _ = plt.ylabel('OP_CARRIER_FL_NUM')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['OP_CARRIER_FL_NUM'].plot(kind='line', figsize=(8, 4), title='OP_CARRIER_FL_NUM')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['DEP_DELAY'].plot(kind='line', figsize=(8, 4), title='DEP_DELAY')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['DEP_DELAY_NEW'].plot(kind='line', figsize=(8, 4), title='DEP_DELAY_NEW')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['DEP_DEL15'].plot(kind='line', figsize=(8, 4), title='DEP_DEL15')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['ORIGIN'].value_counts()
#     for x_label, grp in _df_20.groupby('TAIL_NUM')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('TAIL_NUM')
# _ = plt.ylabel('ORIGIN')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['ORIGIN_CITY_NAME'].value_counts()
#     for x_label, grp in _df_21.groupby('ORIGIN')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('ORIGIN')
# _ = plt.ylabel('ORIGIN_CITY_NAME')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['ORIGIN_STATE_NM'].value_counts()
#     for x_label, grp in _df_22.groupby('ORIGIN_CITY_NAME')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('ORIGIN_CITY_NAME')
# _ = plt.ylabel('ORIGIN_STATE_NM')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['DEST'].value_counts()
#     for x_label, grp in _df_23.groupby('ORIGIN_STATE_NM')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('ORIGIN_STATE_NM')
# _ = plt.ylabel('DEST')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['TAIL_NUM'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='OP_CARRIER_FL_NUM', y='TAIL_NUM', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['ORIGIN'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='OP_CARRIER_FL_NUM', y='ORIGIN', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['ORIGIN_CITY_NAME'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='OP_CARRIER_FL_NUM', y='ORIGIN_CITY_NAME', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_27['ORIGIN_STATE_NM'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_27, x='OP_CARRIER_FL_NUM', y='ORIGIN_STATE_NM', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# Warning: Total number of columns (26) exceeds max_columns (20) limiting to first (20) columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2229453 entries, 0 to 2229452
# Data columns (total 26 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_UNIQUE_CARRIER    object
#  2   TAIL_NUM             object
#  3   OP_CARRIER_FL_NUM    int64
#  4   ORIGIN               object
#  5   ORIGIN_CITY_NAME     object
#  6   ORIGIN_STATE_NM      object
#  7   DEST                 object
#  8   DEST_CITY_NAME       object
#  9   DEST_STATE_NM        object
#  10  DEP_DELAY            float64
#  11  DEP_DELAY_NEW        float64
#  12  DEP_DEL15            float64
#  13  ARR_DELAY            float64
#  14  ARR_DELAY_NEW        float64
#  15  ARR_DEL15            float64
#  16  CANCELLED            float64
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  DISTANCE             float64
#  21  CARRIER_DELAY        float64
#  22  WEATHER_DELAY        float64
#  23  NAS_DELAY            float64
#  24  SECURITY_DELAY       float64
#  25  LATE_AIRCRAFT_DELAY  float64
# dtypes: float64(16), int64(1), object(9)
# memory usage: 442.2+ MB

# %%
df.isnull().sum()
# Out:
# FL_DATE                      0
# OP_UNIQUE_CARRIER            0
# TAIL_NUM                  4606
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# ORIGIN_CITY_NAME             0
# ORIGIN_STATE_NM              0
# DEST                         0
# DEST_CITY_NAME               0
# DEST_STATE_NM                0
# DEP_DELAY                34338
# DEP_DELAY_NEW            34338
# DEP_DEL15                34338
# ARR_DELAY                40677
# ARR_DELAY_NEW            40677
# ARR_DEL15                40677
# CANCELLED                    0
# DIVERTED                     0
# CRS_ELAPSED_TIME             0
# ACTUAL_ELAPSED_TIME      40677
# DISTANCE                     0
# CARRIER_DELAY          1798583
# WEATHER_DELAY          1798583
# NAS_DELAY              1798583
# SECURITY_DELAY         1798583
# LATE_AIRCRAFT_DELAY    1798583
# dtype: int64

# %%
# Top 5 airlines by number of flights
df['OP_UNIQUE_CARRIER'].value_counts().head()
# Out:
# OP_UNIQUE_CARRIER
# WN    445560
# DL    316314
# AA    309761
# OO    264678
# UA    250885
# Name: count, dtype: int64

# %%
# Average arrival delay by the airline
df.groupby('OP_UNIQUE_CARRIER').ARR_DELAY.mean().head()
# Out:
# OP_UNIQUE_CARRIER
# AA     8.978682
# AS     1.297980
# B6     6.144966
# DL     4.194200
# F9    11.316228
# Name: ARR_DELAY, dtype: float64

# %%
# To show in descending order
df.groupby("OP_UNIQUE_CARRIER").ARR_DELAY.mean().sort_values(ascending=False).head()
# Out:
# OP_UNIQUE_CARRIER
# OH    17.155742
# F9    11.316228
# G4     9.537140
# AA     8.978682
# OO     7.590935
# Name: ARR_DELAY, dtype: float64

# %% [markdown]
# OO is the least delayed - arrival

# %% [markdown]
# OH is the most delayed - arrival

# %%
# Let's find the top busiest airports
df['ORIGIN'].value_counts().head()
# Out:
# ORIGIN
# DFW    100777
# DEN     99483
# ATL     98479
# ORD     92348
# PHX     68864
# Name: count, dtype: int64

# %%
# Let's save the df to a csv file for future data use
df.to_csv('Flight_Delay_JanApr2025.csv', index = False)

# %%
df = pd.read_csv('Flight_Delay_JanApr2025.csv')

# %%
df.columns
# Out:
# Index(['FL_DATE', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST',
#        'DEST_CITY_NAME', 'DEST_STATE_NM', 'DEP_DELAY', 'DEP_DELAY_NEW',
#        'DEP_DEL15', 'ARR_DELAY', 'ARR_DELAY_NEW', 'ARR_DEL15', 'CANCELLED',
#        'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY'],
#       dtype='object')
